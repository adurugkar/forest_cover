# %%
url = r"https://www.kaggle.com/c/forest-cover-type-prediction/data"

# %%
from six.moves import urllib
import pandas as pd
import numpy as np
import os

# %%
import tarfile
path=r'c:/Users/avina/Desktop/forest_cover_type'

# %%
from re import I


file = urllib.request.urlretrieve(url)
for i in file:
    print(I)
# Out:
# re.IGNORECASE
# re.IGNORECASE

# %%
with tarfile.open('w+') as housing_tgz_file_obj:
            housing_tgz_file_obj.extractall(path='w+.tgz')
# Out:
# ---------------------------------------------------------------------------
# ReadError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3264/3306467570.py in <module>
# ----> 1 with tarfile.open('w+') as housing_tgz_file_obj:
#       2             housing_tgz_file_obj.extractall(path='w+.tgz')
#
# c:\Users\avina\anaconda3\lib\tarfile.py in open(cls, name, mode, fileobj, bufsize, **kwargs)
#    1614                         fileobj.seek(saved_pos)
#    1615                     continue
# -> 1616             raise ReadError("file could not be opened successfully")
#    1617
#    1618         elif ":" in mode:
#
# ReadError: file could not be opened successfully

# %%
import requests

url="https://www.kaggle.com/louise2001/quantum-physics-articles-on-arxiv-1994-to-2009/download"

r = requests.get(url)

pd.DataFrame(r)
# Out:
#                                                     0
# 0   b'\r\n\r\n<!DOCTYPE html>\r\n<html lang="en">\...
# 1   b'\r\n    <meta name="robots" content="index, ...
# 2   b'ata science community with powerful tools an...
# 3   b'ks-cache-control" content="no-cache" />\r\n ...
# 4   b'=5.0, minimum-scale=1.0">\r\n  <meta name="t...
# 5   b't/javascript">\r\n    window["pageRequestSta...
# 6   b'ow["initialPageLoadStartTime"] = new Date()....
# 7   b'.com" crossorigin="anonymous" /><link rel="p...
# 8   b'ps://storage.googleapis.com" /><link rel="pr...
# 9   b'o" rel="shortcut icon" type="image/x-icon" /...
# 10  b'ials">\r\n\r\n\r\n  <link rel="preconnect" h...
# 11  b'/icon?family=Google+Material+Icons"\r\n    r...
# 12  b'r:400,400i,500,500i,600,600i,700,700i"\r\n  ...
# 13  b'Google+Material+Icons"\r\n    rel="styleshee...
# 14  b'om/css?family=Inter:400,400i,500,500i,600,60...
# 15  b'ipt nonce="8XM2s5ZKWv07fJtR7yJ27g==" type="t...
# ...
